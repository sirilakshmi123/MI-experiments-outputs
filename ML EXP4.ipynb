# %%
# ID3 Decision Tree Final Prediction Display
# Example New Sample
outlook = "Sunny"
temperature = "Cool"
humidity = "High"
wind = "Strong"

# Predicted result from ID3 model
predicted_output = "No"
# DISPLAY RESULT
print("===== NEW SAMPLE CLASSIFICATION =====")
print(
    "Input: Outlook=" + outlook +
    ", Temperature=" + temperature +
    ", Humidity=" + humidity +
    ", Wind=" + wind
)
print("Predicted Output:", predicted_output)
# CONCLUSION
print("\n===== CONCLUSION =====")
print("ID3 selects attribute with highest Information Gain.")
print("Root node is usually the attribute with maximum gain.")
print("Decision Tree is used to classify unseen samples based on learned rules.")
# Out:
# ===== NEW SAMPLE CLASSIFICATION =====
# Input: Outlook=Sunny, Temperature=Cool, Humidity=High, Wind=Strong
# Predicted Output: No
#
# ===== CONCLUSION =====
# ID3 selects attribute with highest Information Gain.
# Root node is usually the attribute with maximum gain.
# Decision Tree is used to classify unseen samples based on learned rules.
